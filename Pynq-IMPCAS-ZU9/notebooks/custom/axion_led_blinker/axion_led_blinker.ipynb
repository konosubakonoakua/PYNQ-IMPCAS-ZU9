# %%
import time

from pynq import Overlay
from pynq import MMIO
from pynq.lib import AxiGPIO

# %%
ol = Overlay('axion_led_blinker.xsa')

# %%
ol.timestamp

# %%
ol.ip_dict.keys()

# %%
ip_led_blinker = ol.ip_dict['led_blinker_axion_reg_0']

# %%
mmio_led_blinker = MMIO(ip_led_blinker['phys_addr'], ip_led_blinker['addr_range'])

# %%
hex(mmio_led_blinker.read(0x4))

# %%
ip_led_blinker
